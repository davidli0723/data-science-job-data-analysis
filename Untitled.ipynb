# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_html('https://www.cse.unsw.edu.au/~cs9321/24T1/ass1/cost_of_living.html')

# %%
df.query('work_year == 2023')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/computation/scope.py:231, in Scope.resolve(self, key, is_local)
#     230 if self.has_resolvers:
# --> 231     return self.resolvers[key]
#     233 # if we're here that means that we have no locals and we also have
#     234 # no resolvers
#
# File /opt/anaconda3/lib/python3.11/collections/__init__.py:1006, in ChainMap.__getitem__(self, key)
#    1005         pass
# -> 1006 return self.__missing__(key)
#
# File /opt/anaconda3/lib/python3.11/collections/__init__.py:998, in ChainMap.__missing__(self, key)
#     997 def __missing__(self, key):
# --> 998     raise KeyError(key)
#
# KeyError: 'work_year'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df = df[0]

# %%
df
# Out:
#      Rank         Country  Cost of Living Index  Rent Index  \
# 0     NaN         Bermuda                 141.8        96.3
# 1     NaN     Switzerland                 114.2        50.2
# 2     NaN  Cayman Islands                 103.4        75.7
# 3     NaN         Bahamas                  90.9        39.6
# 4     NaN        Barbados                  88.8        21.2
# ..    ...             ...                   ...         ...
# 135   NaN           Libya                  24.2         5.2
# 136   NaN        Colombia                  23.1         7.0
# 137   NaN           India                  22.4         5.5
# 138   NaN           Egypt                  21.6         4.3
# 139   NaN        Pakistan                  18.0         3.4
#
#      Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                             120.0            143.3                   142.0
# 1                              83.5            113.9                   109.5
# ...

# %%
df.columns = df.columns.str.replace(' ', '_')
df.columns = df.columns.str.lower()

# %%
df
# Out:
#      rank         country  cost_of_living_index  rent_index  \
# 0     NaN         Bermuda                 141.8        96.3
# 1     NaN     Switzerland                 114.2        50.2
# 2     NaN  Cayman Islands                 103.4        75.7
# 3     NaN         Bahamas                  90.9        39.6
# 4     NaN        Barbados                  88.8        21.2
# ..    ...             ...                   ...         ...
# 135   NaN           Libya                  24.2         5.2
# 136   NaN        Colombia                  23.1         7.0
# 137   NaN           India                  22.4         5.5
# 138   NaN           Egypt                  21.6         4.3
# 139   NaN        Pakistan                  18.0         3.4
#
#      cost_of_living_plus_rent_index  groceries_index  restaurant_price_index  \
# 0                             120.0            143.3                   142.0
# 1                              83.5            113.9                   109.5
# ...

# %%
df.to_csv('q2_text.csv', index=False)

# %%
# ----------------------End of Q2-----------------------

# %%
df = pd.read_html('https://www.cse.unsw.edu.au/~cs9321/24T1/ass1/exchange_rates.html')
df = df[0]
df
# Out:
#            Country Average rate for year ended              \
#            Country                   30 Jun 23   31 Dec 23
# 0           Canada                          na          na
# 1            China                      4.6826      4.7044
# 2           Europe                      0.6439      0.6144
# 3        Hong Kong                      5.2775      5.2013
# 4            India                     54.9312     54.8696
# 5        Indonesia                  10201.7240  10122.2960
# 6            Japan                     92.4880     93.3232
# 7         Malaysia                      3.0252      3.0297
# 8           Taiwan                     20.6747     20.6955
# 9      New Zealand                      1.0928      1.0821
# 10     Philippines                          na     36.9584
# 11       Singapore                      0.9187      0.8922
# 12    South Korean                    890.2842    867.5052
# 13     Switzerland                      0.6322      0.5976
# ...

# %%
df.columns
# Out:
# MultiIndex([(                     'Country',    'Country'),
#             ( 'Average rate for year ended',  '30 Jun 23'),
#             ( 'Average rate for year ended',  '31 Dec 23'),
#             ('Nearest actual exchange rate',  '30 Jun 23'),
#             ('Nearest actual exchange rate', '31 Dec 23*'),
#             (                    'Currency',   'Currency')],
#            )

# %%
df.drop(columns='Nearest actual exchange rate', inplace=True)
df
# Out:
# /var/folders/pt/8p9w36290ms15w_t5l6pm9sr0000gn/T/ipykernel_82251/57985979.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df.drop(columns='Nearest actual exchange rate', inplace=True)
#            Country Average rate for year ended              \
#            Country                   30 Jun 23   31 Dec 23
# 0           Canada                          na          na
# 1            China                      4.6826      4.7044
# 2           Europe                      0.6439      0.6144
# 3        Hong Kong                      5.2775      5.2013
# 4            India                     54.9312     54.8696
# 5        Indonesia                  10201.7240  10122.2960
# 6            Japan                     92.4880     93.3232
# 7         Malaysia                      3.0252      3.0297
# 8           Taiwan                     20.6747     20.6955
# 9      New Zealand                      1.0928      1.0821
# ...

# %%
df.columns = map(lambda x: x[1], df.columns)
list(df.columns)
# Out:
# ['Country', '30\xa0Jun 23', '31\xa0Dec 23', 'Currency']

# %%
df.columns = df.columns.str.replace('\xa0', ' ')
df.columns = df.columns.str.lower()
list(df.columns)
# Out:
# ['country', '30 jun 23', '31 dec 23', 'currency']

# %%
df.drop(columns='30 jun 23', inplace=True)

# %%
df.rename(columns={'31 dec 23': 'rate'}, inplace=True)

# %%
list(df.columns)
# Out:
# ['country', 'rate', 'currency']

# %%
# ----------------------End of Q3-----------------------

# %%
df = pd.read_html('https://www.cse.unsw.edu.au/~cs9321/24T1/ass1/country_codes.html')
df = df[0]
df
# Out:
#     Code Country name (using title case)  Year ccTLD  \
# 0     AD                         Andorra  1974   .ad
# 1     AE            United Arab Emirates  1974   .ae
# 2     AF                     Afghanistan  1974   .af
# 3     AG             Antigua and Barbuda  1974   .ag
# 4     AI                        Anguilla  1985   .ai
# ..   ...                             ...   ...   ...
# 244   YE                           Yemen  1974   .ye
# 245   YT                         Mayotte  1993   .yt
# 246   ZA                    South Africa  1974   .za
# 247   ZM                          Zambia  1974   .zm
# 248   ZW                        Zimbabwe  1980   .zw
#
#                                                  Notes
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# ...

# %%
# df = df.iloc[:, :-3]
df.drop(columns=['Year', 'ccTLD', 'Notes'], inplace=True)
df.rename(columns={'Country name (using title case)': 'country', 'Code': 'code'}, inplace=True)
df
# Out:
#     code               country
# 0     AD               Andorra
# 1     AE  United Arab Emirates
# 2     AF           Afghanistan
# 3     AG   Antigua and Barbuda
# 4     AI              Anguilla
# ..   ...                   ...
# 244   YE                 Yemen
# 245   YT               Mayotte
# 246   ZA          South Africa
# 247   ZM                Zambia
# 248   ZW              Zimbabwe
#
# [249 rows x 2 columns]

# %%
df
# Out:
#     code               country
# 0     AD               Andorra
# 1     AE  United Arab Emirates
# 2     AF           Afghanistan
# 3     AG   Antigua and Barbuda
# 4     AI              Anguilla
# ..   ...                   ...
# 244   YE                 Yemen
# 245   YT               Mayotte
# 246   ZA          South Africa
# 247   ZM                Zambia
# 248   ZW              Zimbabwe
#
# [249 rows x 2 columns]

# %%
# ----------------------End of Q4-----------------------

# %%
data = [{'b': 2, 'c': 3}, {'a': 10, 'b': 20, 'c': 30}]
 
# Creates pandas DataFrame by passing
# Lists of dictionaries and row index.
df = pd.DataFrame(data, index=['first'])
 
# Print the data
print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[589], line 5
#       1 data = [{'b': 2, 'c': 3}, {'a': 10, 'b': 20, 'c': 30}]
#       3 # Creates pandas DataFrame by passing
#       4 # Lists of dictionaries and row index.
# ----> 5 df = pd.DataFrame(data, index=['first'])
#       7 # Print the data
#       8 print(df)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:814, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     805         columns = ensure_index(columns)
#     806     arrays, columns, index = nested_data_to_arrays(
#     807         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     808         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#    (...)
#     812         dtype,
#     813     )
# --> 814     mgr = arrays_to_mgr(
#     815         arrays,
#     816         columns,
# ...

# %%
df = pd.read_csv("ds_jobs.csv")

# %%
df.loc['observations'] = 0
df.loc['distinct'] = 0
df.loc['missing'] = 0
df
# Out:
#               work_year experience_level employment_type  \
# 0                  2023               SE              FT
# 1                  2023               MI              CT
# 2                  2023               MI              CT
# 3                  2023               SE              FT
# 4                  2023               SE              FT
# ...                 ...              ...             ...
# 3753               2020               EN              CT
# 3754               2021               SE              FT
# observations          0                0               0
# distinct              0                0               0
# missing               0                0               0
#
#                              job_title   salary salary_currency  \
# 0             Principal Data Scientist    80000             EUR
# 1                          ML Engineer    30000             USD
# 2                          ML Engineer    25500             USD
# ...

# %%
num_of_rows = df.shape[0]
num_of_rows

summary_list = []

for column in df:
    number_of_missing = df[column].isna().sum()
    number_of_distinct = df[column].nunique()
    number_of_observartion = num_of_rows - number_of_missing
    summary_list.append([number_of_observartion, number_of_distinct, number_of_missing])
    # missing_list.append(number_of_missing)
    # distinct_list.append(number_of_distinct)
    # observation_list.append(number_of_observartion)
    # df.loc['observations', column] = number_of_observartion
    # df.loc['distinct', column] = number_of_distinct
    # df.loc['missing', column] = number_of_missing
    print(column)


# df
summary_df = pd.DataFrame(summary_list, columns=['observations', 'distinct', 'missing'], index=list(df.columns))
# Out:
# 3755
# work_year
# experience_level
# employment_type
# job_title
# salary
# salary_currency
# salary_in_usd
# employee_residence
# remote_ratio
# company_location
# company_size

# %%
summary_df
# Out:
#                     observations  distinct  missing
# work_year                   3755         4        0
# experience_level            3755         4        0
# employment_type             3755         4        0
# job_title                   3755        93        0
# salary                      3755       815        0
# salary_currency             3755        20        0
# salary_in_usd               3755      1035        0
# employee_residence          3755        78        0
# remote_ratio                3755         3        0
# company_location            3755        72        0
# company_size                3755         3        0

# %%
# ----------------------End of Q5-----------------------

# %%
df = pd.read_csv("ds_jobs.csv")
df.dtypes
# Out:
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %%
def rating(level):
    if level == 'EN':
        return 1
    elif level == 'MI':
        return 2
    elif level == 'SE':
        return 3
    elif level == 'EX':
        return 4

# %%
df['experience_rating'] = df['experience_level'].apply(rating)
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
# ----------------------End of Q6-----------------------

# %%
df1 = pd.read_csv('ds_jobs.csv')
df2 = pd.read_csv('country_codes.csv')

# %%
df1
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
df2
# Out:
#     code               country
# 0     AD               Andorra
# 1     AE  United Arab Emirates
# 2     AF           Afghanistan
# 3     AG   Antigua and Barbuda
# 4     AI              Anguilla
# ..   ...                   ...
# 244   YE                 Yemen
# 245   YT               Mayotte
# 246   ZA          South Africa
# 247   ZM                Zambia
# 248   ZW              Zimbabwe
#
# [249 rows x 2 columns]

# %%
df = pd.merge(df1, df2, how='left', left_on='employee_residence', right_on='code')
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
df.drop(columns='code', inplace=True)

# %%
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
# ----------------------End of Q7-----------------------

# %%
#df from q7
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
q7_df = df.query('work_year == 2023')
q7_df
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023               SE              FT   Principal Data Scientist
# 1          2023               MI              CT                ML Engineer
# 2          2023               MI              CT                ML Engineer
# 3          2023               SE              FT             Data Scientist
# 4          2023               SE              FT             Data Scientist
# ...         ...              ...             ...                        ...
# 1815       2023               SE              FT  Machine Learning Engineer
# 1817       2023               MI              FT             Data Scientist
# 1818       2023               MI              FT             Data Scientist
# 1819       2023               EN              FT              Data Engineer
# 1820       2023               EN              FT              Data Engineer
#
# ...

# %%
q7_df['salary_currency'].unique()
# Out:
# array(['EUR', 'USD', 'HKD', 'INR', 'GBP', 'AUD', 'SGD', 'CAD', 'ILS',
#        'CHF', 'THB', 'PLN', 'BRL'], dtype=object)

# %%
currency_df = pd.read_csv('exchange_rates.csv')
currency_df['rate'] = currency_df['rate'].replace('na', 0)
currency_df['rate'] = pd.to_numeric(currency_df['rate'])
currency_df.dtypes
# Out:
# country      object
# rate        float64
# currency     object
# dtype: object

# %%
exchange_rate = currency_df.query('currency == "United States dollar"')['rate'].iloc[0]
exchange_rate
# Out:
# 0.6644

# %%
df['salary_in_aud'] = df['salary_in_usd']/exchange_rate
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
df['salary_in_aud'] = df['salary_in_aud'].astype('int64')

# %%
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
df.dtypes
# Out:
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# country               object
# salary_in_aud          int64
# dtype: object

# %%
# ----------------------End of Q8-----------------------

# %%
df = pd.read_csv('cost_of_living.csv')
df
# Out:
#      rank         country  cost_of_living_index  rent_index  \
# 0     NaN         Bermuda                 141.8        96.3
# 1     NaN     Switzerland                 114.2        50.2
# 2     NaN  Cayman Islands                 103.4        75.7
# 3     NaN         Bahamas                  90.9        39.6
# 4     NaN        Barbados                  88.8        21.2
# ..    ...             ...                   ...         ...
# 135   NaN           Libya                  24.2         5.2
# 136   NaN        Colombia                  23.1         7.0
# 137   NaN           India                  22.4         5.5
# 138   NaN           Egypt                  21.6         4.3
# 139   NaN        Pakistan                  18.0         3.4
#
#      cost_of_living_plus_rent_index  groceries_index  restaurant_price_index  \
# 0                             120.0            143.3                   142.0
# 1                              83.5            113.9                   109.5
# ...

# %%
df = df[['country', 'cost_of_living_plus_rent_index']]
df
# Out:
#             country  cost_of_living_plus_rent_index
# 0           Bermuda                           120.0
# 1       Switzerland                            83.5
# 2    Cayman Islands                            90.1
# 3           Bahamas                            66.3
# 4          Barbados                            56.4
# ..              ...                             ...
# 135           Libya                            15.1
# 136        Colombia                            15.4
# 137           India                            14.3
# 138           Egypt                            13.3
# 139        Pakistan                            11.0
#
# [140 rows x 2 columns]

# %%
aus_index = df.query('country == "Australia"')['cost_of_living_plus_rent_index'].iloc[0]
aus_index
# Out:
# 57.9

# %%
df.dtypes
# Out:
# country                            object
# cost_of_living_plus_rent_index    float64
# dtype: object

# %%
df['cost_of_living_plus_rent_index'] = df['cost_of_living_plus_rent_index'] / aus_index * 100
df
# Out:
#             country  cost_of_living_plus_rent_index
# 0           Bermuda                      207.253886
# 1       Switzerland                      144.214162
# 2    Cayman Islands                      155.613126
# 3           Bahamas                      114.507772
# 4          Barbados                       97.409326
# ..              ...                             ...
# 135           Libya                       26.079447
# 136        Colombia                       26.597582
# 137           India                       24.697755
# 138           Egypt                       22.970639
# 139        Pakistan                       18.998273
#
# [140 rows x 2 columns]

# %%
df['cost_of_living_plus_rent_index'] = df['cost_of_living_plus_rent_index'].round(1)
df
# Out:
#             country  cost_of_living_plus_rent_index
# 0           Bermuda                           207.3
# 1       Switzerland                           144.2
# 2    Cayman Islands                           155.6
# 3           Bahamas                           114.5
# 4          Barbados                            97.4
# ..              ...                             ...
# 135           Libya                            26.1
# 136        Colombia                            26.6
# 137           India                            24.7
# 138           Egypt                            23.0
# 139        Pakistan                            19.0
#
# [140 rows x 2 columns]

# %%
df['CoL'] = df['cost_of_living_plus_rent_index'].round(1)

# %%
df
# Out:
#             country  cost_of_living_plus_rent_index    CoL
# 0           Bermuda                           207.3  207.3
# 1       Switzerland                           144.2  144.2
# 2    Cayman Islands                           155.6  155.6
# 3           Bahamas                           114.5  114.5
# 4          Barbados                            97.4   97.4
# ..              ...                             ...    ...
# 135           Libya                            26.1   26.1
# 136        Colombia                            26.6   26.6
# 137           India                            24.7   24.7
# 138           Egypt                            23.0   23.0
# 139        Pakistan                            19.0   19.0
#
# [140 rows x 3 columns]

# %%
df.sort_values(by='cost_of_living_plus_rent_index', inplace=True)
df
# Out:
#                country  cost_of_living_plus_rent_index    CoL
# 139           Pakistan                            19.0   19.0
# 138              Egypt                            23.0   23.0
# 137              India                            24.7   24.7
# 134              Nepal                            25.4   25.4
# 135              Libya                            26.1   26.1
# ..                 ...                             ...    ...
# 11   Hong Kong (China)                           123.0  123.0
# 1          Switzerland                           144.2  144.2
# 6            Singapore                           147.8  147.8
# 2       Cayman Islands                           155.6  155.6
# 0              Bermuda                           207.3  207.3
#
# [140 rows x 3 columns]

# %%
# ----------------------End of Q9-----------------------

# %%
from thefuzz import fuzz
from thefuzz import process

# %%
q8_df = pd.read_csv('q8.csv')
q9_df = pd.read_csv('q9.csv')

# %%
q8_df
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023               SE              FT   Principal Data Scientist
# 1          2023               MI              CT                ML Engineer
# 2          2023               MI              CT                ML Engineer
# 3          2023               SE              FT             Data Scientist
# 4          2023               SE              FT             Data Scientist
# ...         ...              ...             ...                        ...
# 1780       2023               SE              FT  Machine Learning Engineer
# 1781       2023               MI              FT             Data Scientist
# 1782       2023               MI              FT             Data Scientist
# 1783       2023               EN              FT              Data Engineer
# 1784       2023               EN              FT              Data Engineer
#
# ...

# %%
def fuzzy_merge(df_1, df_2, key1, key2, threshold=90, limit=1):
    """
    :param df_1: the left table to join
    :param df_2: the right table to join
    :param key1: key column of the left table
    :param key2: key column of the right table
    :param threshold: how close the matches should be to return a match, based on Levenshtein distance
    :param limit: the amount of matches that will get returned, these are sorted high to low
    :return: dataframe with boths keys and matches
    """
    s = df_2[key2].tolist()
    
    m = df_1[key1].apply(lambda x: process.extract(x, s, limit=limit))    
    df_1['matches'] = m
    
    m2 = df_1['matches'].apply(lambda x: ', '.join([i[0] for i in x if i[1] >= threshold]))
    df_1['matches'] = m2
    
    return df_1

# %%
df = fuzzy_merge(q8_df, q9_df, 'country', 'country', threshold=90)

# %%
df
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023               SE              FT   Principal Data Scientist
# 1          2023               MI              CT                ML Engineer
# 2          2023               MI              CT                ML Engineer
# 3          2023               SE              FT             Data Scientist
# 4          2023               SE              FT             Data Scientist
# ...         ...              ...             ...                        ...
# 1780       2023               SE              FT  Machine Learning Engineer
# 1781       2023               MI              FT             Data Scientist
# 1782       2023               MI              FT             Data Scientist
# 1783       2023               EN              FT              Data Engineer
# 1784       2023               EN              FT              Data Engineer
#
# ...

# %%
df['matches'].unique()
# Out:
# array(['Spain', 'United States', 'Canada', 'Germany', 'United Kingdom',
#        'Nigeria', 'Hong Kong (China)', 'Portugal', 'India', 'Netherlands',
#        '', 'France', 'Australia', 'Finland', 'Ukraine', 'Ireland',
#        'Israel', 'Ghana', 'Switzerland', 'Austria', 'Colombia',
#        'Singapore', 'Sweden', 'Slovenia', 'Mexico', 'Uzbekistan',
#        'Thailand', 'Croatia', 'Poland', 'Brazil', 'Kuwait', 'Vietnam',
#        'Cyprus', 'Argentina', 'Armenia', 'Bosnia And Herzegovina',
#        'Kenya', 'Greece', 'Latvia', 'Romania'], dtype=object)

# %%
df = df.query('matches != ""')

# %%
df = pd.merge(df, q9_df, how='left', left_on='matches', right_on='country')
df
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023               SE              FT   Principal Data Scientist
# 1          2023               MI              CT                ML Engineer
# 2          2023               MI              CT                ML Engineer
# 3          2023               SE              FT             Data Scientist
# 4          2023               SE              FT             Data Scientist
# ...         ...              ...             ...                        ...
# 1778       2023               SE              FT  Machine Learning Engineer
# 1779       2023               MI              FT             Data Scientist
# 1780       2023               MI              FT             Data Scientist
# 1781       2023               EN              FT              Data Engineer
# 1782       2023               EN              FT              Data Engineer
#
# ...

# %%
df.drop(['matches', 'country_y'], axis=1, inplace=True)
df.rename(columns={'country_x': 'country', "cost_of_living_plus_rent_index": "cost_of_living"}, inplace=True)
df
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023               SE              FT   Principal Data Scientist
# 1          2023               MI              CT                ML Engineer
# 2          2023               MI              CT                ML Engineer
# 3          2023               SE              FT             Data Scientist
# 4          2023               SE              FT             Data Scientist
# ...         ...              ...             ...                        ...
# 1778       2023               SE              FT  Machine Learning Engineer
# 1779       2023               MI              FT             Data Scientist
# 1780       2023               MI              FT             Data Scientist
# 1781       2023               EN              FT              Data Engineer
# 1782       2023               EN              FT              Data Engineer
#
# ...

# %%
df['matches'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'matches'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[653], line 1
# ----> 1 df['matches'].unique()
#
# ...

# %%
df['country_y'].unique()
# Out:
# array(['Spain', 'United States', 'Canada', 'Germany', 'United Kingdom',
#        'Nigeria', 'Hong Kong (China)', 'Portugal', 'India', 'Netherlands',
#        'France', 'Australia', 'Finland', 'Ukraine', 'Ireland', 'Israel',
#        'Ghana', 'Switzerland', 'Austria', 'Colombia', 'Singapore',
#        'Sweden', 'Slovenia', 'Mexico', 'Uzbekistan', 'Thailand',
#        'Croatia', 'Poland', 'Brazil', 'Kuwait', 'Vietnam', 'Cyprus',
#        'Argentina', 'Armenia', 'Bosnia And Herzegovina', 'Kenya',
#        'Greece', 'Latvia', 'Romania'], dtype=object)

# %%
df1 = pd.DataFrame({'Col1':['Microsoft', 'Google', 'Amazon', 'IBM']})
df2 = pd.DataFrame({'Col2':['Mcrsoft', 'gogle', 'Amason', 'BIM']})

fuzzy_merge(df1, df2, 'Col1', 'Col2', 10)
# Out:
#         Col1        matches
# 0  Microsoft   Mcrsoft, BIM
# 1     Google  gogle, Amason
# 2     Amazon    Amason, BIM
# 3        IBM   BIM, Mcrsoft

# %%
# ----------------------End of Q10-----------------------

# %%
df = pd.DataFrame({"A": ["foo", "foo", "foo", "foo", "foo",
                         "bar", "bar", "bar", "bar"],
                   "B": ["one", "one", "one", "two", "two",
                         "one", "one", "two", "two"],
                   "C": ["small", "large", "large", "small",
                         "small", "large", "small", "small",
                         "large"],
                   "D": [1, 2, 2, 3, 3, 4, 5, 6, 7]})
df
# Out:
#      A    B      C  D
# 0  foo  one  small  1
# 1  foo  one  large  2
# 2  foo  one  large  2
# 3  foo  two  small  3
# 4  foo  two  small  3
# 5  bar  one  large  4
# 6  bar  one  small  5
# 7  bar  two  small  6
# 8  bar  two  large  7

# %%
table = pd.pivot_table(df, values="D", index=['A', 'B'],
                       columns=['C'], aggfunc=np.sum)
table.columns
# Out:
# /var/folders/pt/8p9w36290ms15w_t5l6pm9sr0000gn/T/ipykernel_82251/2985654947.py:1: FutureWarning: The provided callable <function sum at 0x1049ee200> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   table = pd.pivot_table(df, values="D", index=['A', 'B'],
# Index(['large', 'small'], dtype='object', name='C')

# %%
data = {
    'Date': ['2024-01-01', '2024-01-01', '2024-01-02', '2024-01-02', '2024-01-03'],
    'Category': ['A', 'B', 'A', 'B', 'A'],
    'Value': [10, 20, 30, 40, 50]
}

df = pd.DataFrame(data)

# Creating a pivot table with two levels of headers
pivot_table = df.pivot_table(index='Date', columns='Category', values='Value', aggfunc='sum')

# Filling NaN values with 0
pivot_table = pivot_table.fillna(0)

# Sorting columns by 'A' then 'B' in decreasing order
# pivot_table = pivot_table.sort_values(by=['A', 'B'], ascending=False, axis=1)

# Adding a second level of headers
# pivot_table.columns = pd.MultiIndex.from_product([['Total'], pivot_table.columns])

# %%
pivot_table.sort_values(by=['A', 'B'], ascending=False, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/pt/8p9w36290ms15w_t5l6pm9sr0000gn/T/ipykernel_82251/2712895902.py in ?()
# ----> 1 pivot_table.sort_values(by=['A', 'B'], ascending=False, axis=1)
#
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6923                 f"Length of ascending ({len(ascending)})"  # type: ignore[arg-type]
#    6924                 f" != length of by ({len(by)})"
#    6925             )
#    6926         if len(by) > 1:
# -> 6927             keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    6928
#    6929             # need to rewrap columns in Series to apply key function
#    6930             if key is not None:
#
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py in ?(.0)
# ...

# %%
q11_df = df

# %%
pivot_table = pd.pivot_table(q11_df, values="salary_in_aud", index=['country'], columns=['experience_rating'], aggfunc=np.average)
pivot_table
# Out:
# experience_rating                                               1  \
# country
# Argentina                                            45153.000000
# Armenia                                                       NaN
# Australia                                                     NaN
# Austria                                                       NaN
# Bosnia and Herzegovina                              180614.000000
# Brazil                                               29382.000000
# Canada                                               69548.000000
# Colombia                                                      NaN
# Croatia                                                       NaN
# Cyprus                                                        NaN
# Finland                                                       NaN
# France                                                        NaN
# Germany                                             131228.000000
# ...

# %%
# pivot_table.columns = pd.MultiIndex.from_product([['salary_in_aud'], pivot_table.columns])
pivot_table.columns
# Out:
# MultiIndex([('salary_in_aud', 1),
#             ('salary_in_aud', 2),
#             ('salary_in_aud', 3),
#             ('salary_in_aud', 4)],
#            names=[None, 'experience_rating'])

# %%
pivot_table = pivot_table.fillna(0)
pivot_table
# Out:
#                                                     salary_in_aud  \
# experience_rating                                               1
# country
# Argentina                                            45153.000000
# Armenia                                                  0.000000
# Australia                                                0.000000
# Austria                                                  0.000000
# Bosnia and Herzegovina                              180614.000000
# Brazil                                               29382.000000
# Canada                                               69548.000000
# Colombia                                                 0.000000
# Croatia                                                  0.000000
# Cyprus                                                   0.000000
# Finland                                                  0.000000
# France                                                   0.000000
# ...

# %%
pivot_table = pivot_table.astype(int)
pivot_table
# Out:
#                                                    salary_in_aud          \
# experience_rating                                              1       2
# country
# Argentina                                                  45153       0
# Armenia                                                        0   75255
# Australia                                                      0       0
# Austria                                                        0   90447
# Bosnia and Herzegovina                                    180614       0
# Brazil                                                     29382       0
# Canada                                                     69548  173088
# Colombia                                                       0       0
# Croatia                                                        0  137180
# Cyprus                                                         0       0
# Finland                                                        0  112913
# ...

# %%
pivot_table.columns
# Out:
# MultiIndex([('salary_in_aud', 1),
#             ('salary_in_aud', 2),
#             ('salary_in_aud', 3),
#             ('salary_in_aud', 4)],
#            names=[None, 'experience_rating'])

# %%
pivot_table = pivot_table.sort_values(by=list(pivot_table.columns), ascending=False)
pivot_table
# Out:
#                                                    salary_in_aud          \
# experience_rating                                              1       2
# country
# Switzerland                                               182259       0
# Bosnia and Herzegovina                                    180614       0
# United States of America                                  163650  200247
# Sweden                                                    158037       0
# Uzbekistan                                                150511       0
# United Kingdom of Great Britain and Northern Ir...        135460  116791
# Germany                                                   131228       0
# Nigeria                                                    97832       0
# Kuwait                                                     75255       0
# Canada                                                     69548  173088
# Argentina                                                  45153       0
# ...

# %%
# ----------------------End of Q11-----------------------

# %%
df = pd.read_csv('Q10.csv')
df
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023               SE              FT   Principal Data Scientist
# 1          2023               MI              CT                ML Engineer
# 2          2023               MI              CT                ML Engineer
# 3          2023               SE              FT             Data Scientist
# 4          2023               SE              FT             Data Scientist
# ...         ...              ...             ...                        ...
# 1778       2023               SE              FT  Machine Learning Engineer
# 1779       2023               MI              FT             Data Scientist
# 1780       2023               MI              FT             Data Scientist
# 1781       2023               EN              FT              Data Engineer
# 1782       2023               EN              FT              Data Engineer
#
# ...

# %%
# df_uk = df.query('employee_residence == "GB" and experience_rating == 1')
test_df = df.query('cost_of_living > 100')
test_df
# Out:
#       work_year experience_level employment_type                  job_title  \
# 1          2023               MI              CT                ML Engineer
# 2          2023               MI              CT                ML Engineer
# 5          2023               SE              FT          Applied Scientist
# 6          2023               SE              FT          Applied Scientist
# 9          2023               SE              FT             Data Scientist
# ...         ...              ...             ...                        ...
# 1778       2023               SE              FT  Machine Learning Engineer
# 1779       2023               MI              FT             Data Scientist
# 1780       2023               MI              FT             Data Scientist
# 1781       2023               EN              FT              Data Engineer
# 1782       2023               EN              FT              Data Engineer
#
# ...

# %%
test_df['country'].value_counts()
# Out:
# country
# United States of America    1565
# Ireland                        5
# Hong Kong                      1
# Switzerland                    1
# Singapore                      1
# Name: count, dtype: int64

# %%
filter_experience_df = df.query('experience_rating != 4')

# filter_experience_df = df

# %%
filter_experience_df['country'].value_counts()
# Out:
# country
# United States of America                                1507
# United Kingdom of Great Britain and Northern Ireland      64
# Canada                                                    35
# Spain                                                     28
# India                                                     15
# Germany                                                   12
# Mexico                                                     5
# France                                                     5
# Ireland                                                    5
# Latvia                                                     4
# Portugal                                                   4
# Ukraine                                                    3
# Netherlands, Kingdom of the                                3
# Nigeria                                                    3
# Thailand                                                   2
# ...

# %%
# top_nine_country = filter_experience_df['country'].value_counts().head(9).index
# top_nine_country

value_counts = filter_experience_df['country'].value_counts()
value_counts

# Get the values where the count is greater than 5
filtered_values = value_counts[value_counts >= 5].index.tolist()
filtered_values

filter_country_df = filter_experience_df.query('country in @filtered_values or country == "Australia"')
# Out:
# country
# United States of America                                1507
# United Kingdom of Great Britain and Northern Ireland      64
# Canada                                                    35
# Spain                                                     28
# India                                                     15
# Germany                                                   12
# Mexico                                                     5
# France                                                     5
# Ireland                                                    5
# Latvia                                                     4
# Portugal                                                   4
# Ukraine                                                    3
# Netherlands, Kingdom of the                                3
# Nigeria                                                    3
# Thailand                                                   2
# ...

# %%
filter_country_df = filter_experience_df.query('country in @top_nine_country or country == "Australia"')

# %%
filter_country_df['country'].value_counts()
# Out:
# country
# United States of America                                1507
# United Kingdom of Great Britain and Northern Ireland      64
# Canada                                                    35
# Spain                                                     28
# India                                                     15
# Germany                                                   12
# France                                                     5
# Ireland                                                    5
# Mexico                                                     5
# Australia                                                  1
# Name: count, dtype: int64

# %%
filter_country_df
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023               SE              FT   Principal Data Scientist
# 1          2023               MI              CT                ML Engineer
# 2          2023               MI              CT                ML Engineer
# 3          2023               SE              FT             Data Scientist
# 4          2023               SE              FT             Data Scientist
# ...         ...              ...             ...                        ...
# 1776       2023               MI              FT               Data Analyst
# 1777       2023               SE              FT  Machine Learning Engineer
# 1778       2023               SE              FT  Machine Learning Engineer
# 1779       2023               MI              FT             Data Scientist
# 1780       2023               MI              FT             Data Scientist
#
# ...

# %%
q12_pivot_table = pd.pivot_table(filter_country_df, values=["salary_in_aud", "cost_of_living"], index=['country'], aggfunc=np.average)
q12_pivot_table
# Out:
#                                                     cost_of_living  \
# country
# Australia                                                    100.0
# Canada                                                        87.0
# France                                                        82.0
# Germany                                                       78.2
# India                                                         24.7
# Ireland                                                      100.2
# Mexico                                                        44.0
# Spain                                                         63.4
# United Kingdom of Great Britain and Northern Ir...            80.5
# United States of America                                     104.1
#
#                                                     salary_in_aud
# country
# Australia                                           102826.000000
# Canada                                              228356.028571
# ...

# %%
q12_pivot_table = pd.pivot_table(filter_country_df, values=["salary_in_aud", "cost_of_living"], index=['country'], aggfunc=np.average)
q12_pivot_table
# Out:
#                                                     cost_of_living  \
# country
# Australia                                                    100.0
# Canada                                                        87.0
# France                                                        82.0
# Germany                                                       78.2
# India                                                         24.7
# Ireland                                                      100.2
# Mexico                                                        44.0
# Spain                                                         63.4
# United Kingdom of Great Britain and Northern Ir...            80.5
# United States of America                                     104.1
#
#                                                     salary_in_aud
# country
# Australia                                           102826.000000
# Canada                                              228356.028571
# ...

# %%
pivot_table
# Out:
#                                                    salary_in_aud          \
# experience_rating                                              1       2
# country
# Switzerland                                               182259       0
# Bosnia and Herzegovina                                    180614       0
# United States of America                                  163650  200247
# Sweden                                                    158037       0
# Uzbekistan                                                150511       0
# United Kingdom of Great Britain and Northern Ir...        135460  116791
# Germany                                                   131228       0
# Nigeria                                                    97832       0
# Kuwait                                                     75255       0
# Canada                                                     69548  173088
# Argentina                                                  45153       0
# ...

# %%
import matplotlib.pyplot as plt

# Data from the pivot table
countries = [
    "Australia", "Canada", "France", "Germany", "India",
    "Ireland", "Mexico", "Spain", "United Kingdom of Great Britain and Northern Ireland", "United States of America"
]
cost_of_living = [100.0, 87.0, 82.0, 78.2, 24.7, 100.2, 44.0, 63.4, 80.5, 104.1]
salary_in_aud = [102826.0, 237980.757576, 102487.0, 242033.375, 44439.0, 169777.6, 122817.2, 115173.62963, 134123.854839, 237879.801973]

# Create scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(cost_of_living, salary_in_aud, color='blue')

# Add labels and title
plt.title('Cost of Living vs. Salary')
plt.xlabel('Cost of Living Index')
plt.ylabel('Average Salary in AUD')

# Add country labels
for i, country in enumerate(countries):
    plt.annotate(country, (cost_of_living[i], salary_in_aud[i]), textcoords="offset points", xytext=(0,10), ha='center')

# plt.grid(True)
plt.show()
# Out:
# Text(0.5, 1.0, 'Cost of Living vs. Salary')
# Text(0.5, 0, 'Cost of Living Index')
# Text(0, 0.5, 'Average Salary in AUD')
# Text(0, 10, 'Australia')
# Text(0, 10, 'Canada')
# Text(0, 10, 'France')
# Text(0, 10, 'Germany')
# Text(0, 10, 'India')
# Text(0, 10, 'Ireland')
# Text(0, 10, 'Latvia')
# Text(0, 10, 'Mexico')
# Text(0, 10, 'Spain')
# Text(0, 10, 'United Kingdom of Great Britain and Northern Ireland')
# Text(0, 10, 'United States of America')

# %%
import matplotlib.pyplot as plt

# Data from the pivot table
countries = [
    "Australia", "Canada", "France", "Germany", "India",
    "Ireland", "Mexico", "Spain", "United Kingdom of Great Britain and Northern Ireland", "United States of America"
]
cost_of_living = [100.0, 87.0, 82.0, 78.2, 24.7, 100.2, 44.0, 63.4, 80.5, 104.1]
salary_in_aud = [102826.0, 237980.757576, 102487.0, 242033.375, 44439.0, 169777.6, 122817.2, 115173.62963, 134123.854839, 237879.801973]

# Create scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(cost_of_living, salary_in_aud, color='blue')

# Add labels and title
plt.title('Cost of Living vs. Salary')
plt.xlabel('Cost of Living Index')
plt.ylabel('Average Salary in AUD')

# Add country labels
for i, country in enumerate(countries):
    plt.annotate(country, (cost_of_living[i], salary_in_aud[i]), textcoords="offset points", xytext=(0,10), ha='center')

plt.grid(True)
plt.show()
# Out:
# Text(0.5, 1.0, 'Cost of Living vs. Salary')
# Text(0.5, 0, 'Cost of Living Index')
# Text(0, 0.5, 'Average Salary in AUD')
# Text(0, 10, 'Australia')
# Text(0, 10, 'Canada')
# Text(0, 10, 'France')
# Text(0, 10, 'Germany')
# Text(0, 10, 'India')
# Text(0, 10, 'Ireland')
# Text(0, 10, 'Mexico')
# Text(0, 10, 'Spain')
# Text(0, 10, 'United Kingdom of Great Britain and Northern Ireland')
# Text(0, 10, 'United States of America')

# %%
q12_pivot_table.rename(index={'United States of America': 'US', 'United Kingdom of Great Britain and Northern Ireland': 'UK'}, inplace=True)
q12_pivot_table
# Out:
#            cost_of_living  salary_in_aud
# country
# Australia           100.0  102826.000000
# Canada               87.0  228356.028571
# France               82.0  102487.000000
# Germany              78.2  205098.250000
# India                24.7   44010.000000
# Ireland             100.2  169777.600000
# Mexico               44.0  122817.200000
# Spain                63.4  112213.892857
# UK                   80.5  134165.625000
# US                  104.1  233545.228268

# %%
df1 = q12_pivot_table.reset_index()

# Extract required columns
cost_of_living = df1['cost_of_living']
salary_in_aud = df1['salary_in_aud']
countries = df1['country']

# Plot scatter chart
plt.figure(figsize=(12, 8))
plt.scatter(cost_of_living, salary_in_aud, color='blue')

# Add labels and title
plt.xlabel('Cost of Living')
plt.ylabel('Salary in AUD')
plt.title('Scatter Plot of Cost of Living vs Salary')

# Add country labels
for i, country in enumerate(countries):
    plt.annotate(country, (cost_of_living[i], salary_in_aud[i]), textcoords="offset points", xytext=(0,5), ha='center', fontsize=10)

# plt.grid(True)
plt.show()
# Out:
# Text(0.5, 0, 'Cost of Living')
# Text(0, 0.5, 'Salary in AUD')
# Text(0.5, 1.0, 'Scatter Plot of Cost of Living vs Salary')
# Text(0, 5, 'Australia')
# Text(0, 5, 'Canada')
# Text(0, 5, 'France')
# Text(0, 5, 'Germany')
# Text(0, 5, 'India')
# Text(0, 5, 'Ireland')
# Text(0, 5, 'Mexico')
# Text(0, 5, 'Spain')
# Text(0, 5, 'UK')
# Text(0, 5, 'US')

# %%
df1 = q12_pivot_table.reset_index()
df1
# Out:
#                                              country  cost_of_living  \
# 0                                          Australia           100.0
# 1                                             Canada            87.0
# 2                                             France            82.0
# 3                                            Germany            78.2
# 4                                              India            24.7
# 5                                            Ireland           100.2
# 6                                             Mexico            44.0
# 7                                              Spain            63.4
# 8  United Kingdom of Great Britain and Northern I...            80.5
# 9                           United States of America           104.1
#
#    salary_in_aud
# 0  102826.000000
# 1  228356.028571
# 2  102487.000000
# 3  205098.250000
# 4   44010.000000
# 5  169777.600000
# 6  122817.200000
# 7  112213.892857
# 8  134165.625000
# 9  233545.228268

# %%
q10 = pd.read_csv('Q10.csv')
q10
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023               SE              FT   Principal Data Scientist
# 1          2023               MI              CT                ML Engineer
# 2          2023               MI              CT                ML Engineer
# 3          2023               SE              FT             Data Scientist
# 4          2023               SE              FT             Data Scientist
# ...         ...              ...             ...                        ...
# 1778       2023               SE              FT  Machine Learning Engineer
# 1779       2023               MI              FT             Data Scientist
# 1780       2023               MI              FT             Data Scientist
# 1781       2023               EN              FT              Data Engineer
# 1782       2023               EN              FT              Data Engineer
#
# ...

# %%
q10_canada = q10.query('country == "Canada" and experience_rating == 2')

# %%
q10_canada
# Out:
#      work_year experience_level employment_type     job_title  salary  \
# 790       2023               MI              FT  Data Analyst  130000
# 791       2023               MI              FT  Data Analyst  100000
#
#     salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 790             USD         130000                 CA           100
# 791             USD         100000                 CA           100
#
#     company_location company_size  experience_rating country  salary_in_aud  \
# 790               CA            M                  2  Canada         195665
# 791               CA            M                  2  Canada         150511
#
#      cost_of_living
# 790            87.0
# 791            87.0
